# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,20,100)

plt.figure(figsize=(8,6))
plt.plot(x,x)
plt.title("Función Lineal ${f(x)=x}$");
plt.ylabel("Y") 
plt.xlabel("X")
plt.xticks([0,5,20])
# Out:
# ([<matplotlib.axis.XTick at 0x1efd635c640>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
def cudratica(x)
